# %% [markdown]
# **This Notebook contains**
#
# _**JSON Partner Configurations**_
#
# The pipeline reads partner metadata from a single configuration file.
# New partners can be onboarded by adding a new entry to the config, without modifying pipeline code.

# %%
{
  "output": {
    "unified_path": "/Volumes/workspace/default/eligibility_volume/Output/unified",
    "rejects_path": "/Volumes/workspace/default/eligibility_volume/Output/rejects",
    "write_mode": "overwrite",
    "coalesce_to_one_file": true
  },
  "partners": [
    {
      "partner_key": "acme_health",
      "partner_code": "ACME",
      "file_path": "/Volumes/workspace/default/eligibility_volume/Input/acme.txt",
      "delimiter": "|",
      "has_header": true,
      "column_mapping": {
        "MBI": "external_id",
        "FNAME": "first_name",
        "LNAME": "last_name",
        "DOB": "dob",
        "EMAIL": "email",
        "PHONE": "phone"
      }
    },
    {
      "partner_key": "better_care",
      "partner_code": "BCARE",
      "file_path": "/Volumes/workspace/default/eligibility_volume/Input/better_care.csv",
      "delimiter": ",",
      "has_header": true,
      "column_mapping": {
        "subscriber_id": "external_id",
        "first_name": "first_name",
        "last_name": "last_name",
        "date_of_birth": "dob",
        "email": "email",
        "phone": "phone"
      }
    },
    {
      "partner_key": "regional_health",
      "partner_code": "UHSHEALTH",
      "file_path": "/Volumes/workspace/default/eligibility_volume/Input/unitedhealthsystem.csv",
      "delimiter": ";",
      "has_header": true,
      "column_mapping": {
        "member_id": "external_id",
        "first_name": "first_name",
        "last_name": "last_name",
        "date_of_birth": "dob",
        "email": "email",
        "phone": "phone"
      }
    }
  ],
  "validation": {
    "external_id_required": true,
    "phone_digits_required": 10
  }
}
