# %% [markdown]
# ## THIS NOTEBOOK CONTAINS
#
# **The Two Partners ACME & Better Care Rejects & Unified Tables**

# %% [markdown]
# _**Rejects Dataset**_
#
# For the ACME and Better Care input files used in this run, all records met the
# validation requirements, so no rows were routed to the rejects dataset. Validation
# and error-handling logic (e.g., missing external_id, invalid date formats) is
# implemented in the pipeline and demonstrated in a separate extensibility test
# with a third partner.
# **

# %%
rejects_df = spark.read \
  .option("header", "true") \
  .csv("/Volumes/workspace/default/eligibility_volume/Output/rejects")

display(rejects_df)

# %% [markdown]
# **_Unified Dataset_**
#
# The unified dataset contains all valid eligibility records from the ACME and Better Care
# input files after schema standardization and data cleansing. Each record conforms to the
# common output schema and includes a partner_code to identify the source system.

# %%
Unified_df = spark.read \
  .option("header", "true") \
  .csv("/Volumes/workspace/default/eligibility_volume/Output/unified")

display(Unified_df)

# %% [markdown]
# ![](/Volumes/workspace/default/eligibility_volume/Screenshot 2026-01-14 203949.png)
